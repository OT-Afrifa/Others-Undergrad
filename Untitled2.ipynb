# %%
import xarray as xr

# %%
data = xr.open_dataset('Specific_humidity.nc')

# %%
data = data.q

# %%
t = data.sel(time = '2018')

# %%
y = t.mean(['latitude','longitude'])

# %%
t
# Out:
# <xarray.DataArray 'q' (time: 72, level: 27, latitude: 45, longitude: 121)>
# array([[[[2.829358e-06, ..., 3.525056e-06],
#          ...,
#          [3.525056e-06, ..., 3.872439e-06]],
#
#         ...,
#
#         [[1.355115e-02, ..., 1.077880e-02],
#          ...,
#          [1.587442e-02, ..., 1.673744e-02]]],
#
#
#        ...,
#
#
#        [[[3.872439e-06, ..., 3.176741e-06],
#          ...,
#          [3.525056e-06, ..., 3.872439e-06]],
#
#         ...,
#
#         [[1.485071e-02, ..., 1.292120e-02],
#          ...,
#          [1.478392e-02, ..., 1.726373e-02]]]], dtype=float32)
# Coordinates:
#   * longitude  (longitude) float32 -20.0 -19.75 -19.5 -19.25 ... 9.5 9.75 10.0
#   * latitude   (latitude) float32 15.0 14.75 14.5 14.25 ... 4.75 4.5 4.25 4.0
#   * level      (level) int32 100 125 150 175 200 225 ... 900 925 950 975 1000
#   * time       (time) datetime64[ns] 2018-06-26 ... 2018-06-28T23:00:00
# Attributes:
#     units:          kg kg**-1
# ...

# %%
y.T.plot()
